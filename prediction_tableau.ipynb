# %% [markdown]
# <a href="https://colab.research.google.com/github/AlinaOtr/data/blob/master/prediction_tableau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Задание 2
# Клиент просит сделать приблизительный прогноз трафика и выручки на 2022 на основе исторических данных с момента запуска платформы.

# %%
import pandas as pd

# %% [markdown]
# Это ссылка на файл: https://drive.google.com/file/d/1tmRkNlXidwRRz9blvXNRw691ZlhqbGdD/view?usp=sharing

# %%
# !gdown --id 1tmRkNlXidwRRz9blvXNRw691ZlhqbGdD
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1tmRkNlXidwRRz9blvXNRw691ZlhqbGdD
# To: /content/prediction.csv
# 100% 34.4k/34.4k [00:00<00:00, 25.0MB/s]

# %%
df = pd.read_csv('/content/prediction.csv')

# %%
df.head()
# Out:
#          date  visits  users  buyers  purchases  revenue
# 0  2019-10-01   16365  11766     719       1680  4029453
# 1  2019-10-02   16185  11715     771       1775  4358810
# 2  2019-10-03   15723  11406     752       1671  4449460
# 3  2019-10-04   15722  11410     733       1624  4110221
# 4  2019-10-05   14612  10532     709       1616  4181906

# %%
df.query('users < 15000 and date > "2020-11-04"')
# Out:
#            date  visits  users  buyers  purchases  revenue
# 457  2020-12-31   16796  13606     996       1220  1635626
# 458  2021-01-01   17280  14090     591        692   875911
# 822  2021-12-31   18304  14403    1127       1437  1939218

# %%
df.isna().mean()
# Out:
# date         0.0
# visits       0.0
# users        0.0
# buyers       0.0
# purchases    0.0
# revenue      0.0
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.date.count() == df.date.nunique()
# Out:
# True

# %% [markdown]
# Пропусков и дубликатов в датасете нет.

# %%
df.groupby('date').revenue.agg('sum').plot(ylim = 0, grid = True, figsize=(19, 6))

# %%
df.groupby('date').users.agg('sum').plot(ylim = 0, grid = True, figsize=(19, 6))

# %% [markdown]
# 2 графика в целом похожи, но график с числом посетителей имеет общую тенденцию роста, а график выручки - нет. В январе (вероятно в новогодние праздники) число посетителей каждый год падает.

# %% [markdown]
# Прогноз трафика (users) и выручки (revenue) выполнен в Tableau (см. скрины ниже). Результаты прогноза в файлах .csv

# %% [markdown]
# ![revenue.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![users.jpg](data:image/jpeg;base64,...)
